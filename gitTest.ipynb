# %% [markdown]
# # Jupyter Data Science Workflow

# %%
import pandas as pd
data = pd.read_csv('Fremont_Bridge_Bicycle_Counts_by_Month.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#             Fremont Bridge West Sidewalk  Fremont Bridge East Sidewalk
# Date
# 2014-12-01                         23689                         24818
# 2012-11-01                         26062                         24585
# 2012-12-01                         18608                         17761
# 2015-01-01                         35754                         24876
# 2017-12-01                         18946                         26916

# %%
# %matplotlib inline
data.plot()
